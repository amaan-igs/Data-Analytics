# %%
import pandas as pd
df = pd.read_csv("D:/Datasets/SalesRecords.csv")

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
print(df.columns)
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
# df['column'] if the name of the colum is one word then we can write df.Region
d = df.Region.value_counts()
d
# Out:
# Region
# Sub-Saharan Africa                   36
# Europe                               22
# Australia and Oceania                11
# Asia                                 11
# Middle East and North Africa         10
# Central America and the Caribbean     7
# North America                         3
# Name: count, dtype: int64

# %%
x = d.index
y = d.values

# %%
d.plot.line(x=x, y=y);

# %%
d.plot(x=x, y=y, kind="line");

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
count_by_region = df.Region.value_counts()
count_by_region
# Out:
# Region
# Sub-Saharan Africa                   36
# Europe                               22
# Australia and Oceania                11
# Asia                                 11
# Middle East and North Africa         10
# Central America and the Caribbean     7
# North America                         3
# Name: count, dtype: int64

# %%
 count_by_region.plot(x=x, y=y, kind="bar")
# Out:
# <Axes: xlabel='Region'>

# %%
 count_by_region.plot(x=x, y=y, kind="bar", rot =70)
# Out:
# <Axes: xlabel='Region'>

# %%
 count_by_region.plot(x=x, y=y, kind="bar", rot =10)
# Out:
# <Axes: xlabel='Region'>

# %%
 count_by_region.plot(x=x, y=y, kind="bar", rot =30)
# Out:
# <Axes: xlabel='Region'>

# %%
 count_by_region.plot(x=x, y=y, kind="bar", rot =50)
# Out:
# <Axes: xlabel='Region'>

# %%
count_by_region.plot(x=x,y=y, kind="bar", figsize=(12, 6), title="Sales by region",
                     xlabel="Region", ylabel="Sales", color="green", grid=True, rot=70, fontsize=12)
# Out:
# <Axes: title={'center': 'Sales by region'}, xlabel='Region', ylabel='Sales'>

# %%
count_by_region.plot(x=x,y=y, kind="bar", figsize=(12, 6), title="Sales by region",
                     xlabel="Region", ylabel="Sales", color="blue", grid=True, rot=70, fontsize=12)
# Out:
# <Axes: title={'center': 'Sales by region'}, xlabel='Region', ylabel='Sales'>

# %%
count_by_region.plot(x=x,y=y, kind="bar", figsize=(12, 7), title="Sales by region",
                     xlabel="Region", ylabel="Sales", color="blue", grid=True, rot=90, fontsize=12)
# Out:
# <Axes: title={'center': 'Sales by region'}, xlabel='Region', ylabel='Sales'>

# %%
count_by_region.plot(kind="pie", figsize=(6,6), autopct="%1.1f%%", startangle=90, shadow=True,
                     labels=x, colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue","lightgreen"])
# Out:
# <Axes: ylabel='count'>

# %%
count_by_region.plot(kind="pie", figsize=(8,8), autopct="%1.1f%%", startangle=90, shadow=True,
                     labels=x, colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue","lightgreen"])
# Out:
# <Axes: ylabel='count'>

# %%
count_by_region.plot(kind="pie", figsize=(8,8), startangle=90, shadow=True,
                     labels=x, colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue","lightgreen"])
# Out:
# <Axes: ylabel='count'>

# %%
sales_by_region = df.groupby('Region') ['Total Revenue'].sum()

# %%
sales_by_region
# Out:
# Region
# Asia                                 21347091.02
# Australia and Oceania                14094265.13
# Central America and the Caribbean     9170385.49
# Europe                               33368932.11
# Middle East and North Africa         14052706.58
# North America                         5643356.55
# Sub-Saharan Africa                   39672031.43
# Name: Total Revenue, dtype: float64

# %%
count_by_region.plot(kind="pie", figsize=(6,6), autopct="", startangle=90, shadow=True,
                     labels=x, colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue","lightgreen"])
# Out:
# <Axes: ylabel='count'>

# %%
sales_by_region
# Out:
# Region
# Asia                                 21347091.02
# Australia and Oceania                14094265.13
# Central America and the Caribbean     9170385.49
# Europe                               33368932.11
# Middle East and North Africa         14052706.58
# North America                         5643356.55
# Sub-Saharan Africa                   39672031.43
# Name: Total Revenue, dtype: float64

# %%
sales_by_region.plot(kind="pie", figsize=(8,8), autopct="%1.1f%%", startangle=90, shadow=True,
                     labels=x, colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue","lightgreen"])
# Out:
# <Axes: ylabel='Total Revenue'>

# %%
sales_by_region.plot(kind="pie", figsize=(6,6), autopct="%1.1f%%", startangle=90, shadow=True,
                     labels=x, colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue","lightgreen","Blue","Black"])
# Out:
# <Axes: ylabel='Total Revenue'>

# %%
sales_by_region.plot(kind="pie", figsize=(8,8), autopct="%1.1f%%", startangle=90, shadow=True,
                     labels=x, colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue","lightgreen"])
# Out:
# <Axes: ylabel='Total Revenue'>

# %%
sales_by_region.plot(kind="pie", figsize=(8,8), autopct="%1.1f%%", startangle=90, shadow=True,
                     labels=x, colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue","lightgreen"])
# Out:
# <Axes: ylabel='Total Revenue'>

# %%
sales_by_region
# Out:
# Region
# Asia                                 21347091.02
# Australia and Oceania                14094265.13
# Central America and the Caribbean     9170385.49
# Europe                               33368932.11
# Middle East and North Africa         14052706.58
# North America                         5643356.55
# Sub-Saharan Africa                   39672031.43
# Name: Total Revenue, dtype: float64

# %%
sales_by_region.plot(kind="pie", figsize=(8,8), autopct="%1.1f%%", startangle=90, shadow=True,
                     labels= None, legend = True, colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue","lightgreen"])
# Out:
# <Axes: ylabel='Total Revenue'>

# %%
sales_by_region.plot(kind="pie", figsize=(8,8), autopct="", startangle=90, shadow=False,
                     labels= None, legend = True, colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue","lightgreen"])
# Out:
# <Axes: ylabel='Total Revenue'>

# %%
sales_by_region.plot(kind="pie", figsize=(8,8), autopct="%1.1f%%", startangle=90, shadow=False,
                     labels= None, legend = True, colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue","lightgreen"])
# Out:
# <Axes: ylabel='Total Revenue'>

# %%
#plt.figure(figsize = (15,15))
#plt.title(

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (15,15))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
ax = count_by_region.plot(x=x, y=y, kind="line", legend=False, style = 'r--')
plt.xticks(rotation=5, ha='center') #w/o ";", the output will display
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.]),
#  [Text(-1.0, 0, 'North America'),
#   Text(0.0, 0, 'Sub-Saharan Africa'),
#   Text(1.0, 0, 'Europe'),
#   Text(2.0, 0, 'Australia and Oceania'),
#   Text(3.0, 0, 'Asia'),
#   Text(4.0, 0, 'Middle East and North Africa'),
#   Text(5.0, 0, 'Central America and the Caribbean'),
#   Text(6.0, 0, 'North America'),
#   Text(7.0, 0, '')])

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
ax = count_by_region.plot(x=x, y=y, kind="line", legend=False, style = 'r--')
plt.xticks(rotation=5, ha='center') #w/o ";", the output will display
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.]),
#  [Text(-1.0, 0, 'North America'),
#   Text(0.0, 0, 'Sub-Saharan Africa'),
#   Text(1.0, 0, 'Europe'),
#   Text(2.0, 0, 'Australia and Oceania'),
#   Text(3.0, 0, 'Asia'),
#   Text(4.0, 0, 'Middle East and North Africa'),
#   Text(5.0, 0, 'Central America and the Caribbean'),
#   Text(6.0, 0, 'North America'),
#   Text(7.0, 0, '')])

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
ax = count_by_region.plot(x=x, y=y, kind="line", legend=False, style = 'r')
plt.xticks(rotation=5, ha='center') #w/o ";", the output will display
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.]),
#  [Text(-1.0, 0, 'North America'),
#   Text(0.0, 0, 'Sub-Saharan Africa'),
#   Text(1.0, 0, 'Europe'),
#   Text(2.0, 0, 'Australia and Oceania'),
#   Text(3.0, 0, 'Asia'),
#   Text(4.0, 0, 'Middle East and North Africa'),
#   Text(5.0, 0, 'Central America and the Caribbean'),
#   Text(6.0, 0, 'North America'),
#   Text(7.0, 0, '')])

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
ax = count_by_region.plot(x=x, y=y, kind="line", legend=False, style = 'r*')
plt.xticks(rotation=5, ha='center') #w/o ";", the output will display
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.]),
#  [Text(-1.0, 0, 'North America'),
#   Text(0.0, 0, 'Sub-Saharan Africa'),
#   Text(1.0, 0, 'Europe'),
#   Text(2.0, 0, 'Australia and Oceania'),
#   Text(3.0, 0, 'Asia'),
#   Text(4.0, 0, 'Middle East and North Africa'),
#   Text(5.0, 0, 'Central America and the Caribbean'),
#   Text(6.0, 0, 'North America'),
#   Text(7.0, 0, '')])

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
ax = count_by_region.plot(x=x, y=y, kind="line", legend=False, style = 'r')
plt.xticks(rotation=5, ha='center') 
# adding data labels
for i, j in enumerate(y):
    ax.text(i, j, j, ha='left',va='bottom')
plt.plot(x,y,marker = 'o', c = 'blue')

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
ax = count_by_region.plot(x=x, y=y, kind="line", legend=False, style = 'r')
plt.xticks(rotation=5, ha='center') 
# adding data labels
for i, j in enumerate(y):
    ax.text(i, j, j, ha='left',va='bottom')
plt.plot(x,y,marker = '+', c = 'blue')

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
ax = sales_by_region.plot(x=sales_by_region.index
                          , y=sales_by_region.values, kind="bar", legend=False)
plt.xticks(rotation=5, ha='center') 
# adding data labels using text()
for i, j in enumerate(sales_by_region.values):
    plt.text(i, j,format(j, ',.1f'), color ='black', fontweight='bold', ha='center', va='bottom')

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
ax = sales_by_region.plot(x=sales_by_region.index
                          , y=sales_by_region.values, kind="bar", legend=False)
plt.xticks(rotation=5, ha='center'); 
# adding data labels using text()
for i, j in enumerate(sales_by_region.values):
    plt.text(i, j,format(j, ',.1f'), color ='green', fontweight='bold', ha='center', va='bottom')

# %%
sales_by_region.plot(kind="pie", figsize=(8,8), autopct="", startangle=90, shadow=False,
                     labels= sales_by_region, legend = True, colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue","lightgreen"])
# Out:
# <Axes: ylabel='Total Revenue'>

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
ax = sales_by_region.plot(x=sales_by_region.index
                          , y=sales_by_region.values, kind="bar", legend=False)
plt.xticks(rotation=5, ha='center'); 
# adding data labels using text()
for i, j in enumerate(sales_by_region.values):
    plt.text(i, j,format(j, ',.0f'), color ='green', fontweight='bold', ha='center', va='bottom')

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
ax = sales_by_region.plot(x=sales_by_region.index
                          , y=sales_by_region.values, kind="bar", legend=False)
plt.xticks(rotation=5, ha='center'); 
# adding data labels using text()
for i, j in enumerate(sales_by_region.values):
    plt.text(i, j,format(j, '.0f'), color ='green', fontweight='bold', ha='center', va='bottom')

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
ax = sales_by_region.plot(x=sales_by_region.index
                          , y=sales_by_region.values, kind="barh", legend=False)
plt.xticks(rotation=5, ha='center'); 
# adding data labels using text()
for i, j in enumerate(sales_by_region.values):
    plt.text(j, i,format(j, ',.0f'), color ='green', fontweight='bold', ha='center', va='bottom')

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
ax = sales_by_region.plot(x=sales_by_region.index
                          , y=sales_by_region.values, kind="barh", legend=False)
plt.xticks(rotation=5, ha='center'); 
# adding data labels using text()
for i, j in enumerate(sales_by_region.values):
    plt.text(j, i,format(j, ',.0f'), color ='green', fontweight='bold', ha='center', va='bottom')

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summary')
plt.xlabel('Count')
plt.ylabel('Region')

ax = sales_by_region.plot(kind="barh", legend=False) 

# adding data labels using text()
for i, j in enumerate(sales_by_region):
    ax.annotate(format(j,',.1f'),
                (j, i),
                ha='left', va='center',
                xytext=(5,0),
                       textcoords='offsetpoints')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# ...

# %%
sales_by_region
# Out:
# Region
# Asia                                 21347091.02
# Australia and Oceania                14094265.13
# Central America and the Caribbean     9170385.49
# Europe                               33368932.11
# Middle East and North Africa         14052706.58
# North America                         5643356.55
# Sub-Saharan Africa                   39672031.43
# Name: Total Revenue, dtype: float64

# %%
plt.figure(figsize=(15,5))
plt.title('Region Wise Summary')
plt.xlabel('Count')
plt.ylabel('Region')

ax = sales_by_region.plot(kind='barh', legend=False)

for i,j in enumerate(sales_by_region):
    ax.annotate(format(j,',.1f'), (j,i), ha='left', va='center', xytext=(5, 0), textcoords='offset points')

# %%
df2 = df.groupby(['Region']).agg(TotalRevenue = ('Total Revenue', 'sum'), \
 TotalCost = ('Total Cost', 'sum'), \
 TotalProfit = ('Total Profit', 'sum'))

# %%
ax = df2[['TotalRevenue', 'TotalCost', 'TotalProfit']].plot(kind = 'bar',
                                                           legend = True, figsize = (10,5))

plt.title('Region wise summaray')
plt.xlabel('Region')
plt.ylabel('Count')
plt.xticks(rotation = 90 , ha = 'center')
for p in ax.patches:
 ax.annotate("{:,.1f}".format(p.get_height()),
 (p.get_x() + p.get_width() / 2., p.get_height()),
 ha='center', va='center',
 xytext=(0, 5),
 textcoords='offset points')

# %%
ax = df2[['TotalRevenue', 'TotalCost', 'TotalProfit']].plot(stacked=True, kind='bar', legend = True, figsize = (10,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
plt.xticks(rotation=30, ha='center')
for p in ax.patches:
 ax.annotate("{:,.1f}".format(p.get_height()),
 (p.get_x() + p.get_width() / 2., p.get_y()),
 ha='center', va='bottom',
 xytext=(0, 5),
 textcoords='offset points')

# %%
ax = df2[['TotalRevenue', 'TotalCost', 'TotalProfit']].plot(kind = 'bar',
                                                           legend = True, figsize = (10,5))

plt.title('Region wise summaray')
plt.xlabel('Region')
plt.ylabel('Count')
plt.xticks(rotation = 90 , ha = 'center')
for p in ax.patches:
 ax.annotate("{:,.0f}".format(p.get_height()),
 (p.get_x() + p.get_width() / 2., p.get_height()),
 ha='center', va='center',
 xytext=(0, 5),
 textcoords='offset points')

# %%
ax = df2[['TotalRevenue', 'TotalCost', 'TotalProfit']].plot(stacked=True, kind='barh', legend = True, figsize = (10,5))
plt.title('Region wise Summary')
plt.xlabel('Count')
plt.ylabel('Region')
plt.xticks(rotation=30, ha='center')
for p in ax.patches:
 ax.annotate("{:,.1f}".format(p.get_width()),
 (p.get_x() + p.get_width() / 2., p.get_y()),
 ha='center', va='bottom',
 xytext=(0, 5),
 textcoords='offset points')

# %%
ax = df2[['TotalRevenue', 'TotalCost', 'TotalProfit']].plot(stacked = True, kind = 'barh', legend=True, figsize=(10,5))

plt.title('Region Wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
plt.xticks(rotation=30, ha='center')

for p in ax.patches:
    ax.annotate("{:,.1f}".format(p.get_width()), (p.get_x() + p.get_width(), p.get_y() + p.get_height()/2), ha='center', va='center', xytext=(5, 0), textcoords='offset points', rotation = 90)
    # Save the figure as a PNG file with the specified DPI
fig.savefig('total_revenue_summary.png', dpi=100)

# Display the plot
plt.show()

# %%
ax = df2[['TotalRevenue', 'TotalCost', 'TotalProfit']].plot(kind = 'bar', legend=True, figsize=(10,5))

plt.title('Region Wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
plt.xticks(rotation=30, ha='center')

for p in ax.patches:
    ax.annotate("{:,.1f}".format(p.get_height()), (p.get_x() + p.get_width()/2, p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')

# %%
fig = plt.figure(figsize=(15, 6))
plt.title('Region wise TotalRevenue Summery')

df2.TotalRevenue.plot(kind='pie', autopct='%1.2f%%', wedgeprops={'linewidth': 5, 'edgecolor': 'white'})

plt.legend(title="Regions", loc="center left", bbox_to_anchor=(1, 0.5));

# %%
col_d = ['Order Date', 'Ship Date'];
df[col_d] = df[col_d].apply(pd.to_datetime, format='%m/%d/%Y');
print(df.dtypes);
# Out:
# Region                    object
# Country                   object
# Item Type                 object
# Sales Channel             object
# Order Priority            object
# Order Date        datetime64[ns]
# Order ID                   int64
# Ship Date         datetime64[ns]
# Units Sold                 int64
# Unit Price               float64
# Unit Cost                float64
# Total Revenue            float64
# Total Cost               float64
# Total Profit             float64
# dtype: object

# %%
fig.savefig('test2png.png', dpi=100)

# %%
# Create the figure and set its size
fig = plt.figure(figsize=(15, 6))

# Set the title of the plot
plt.title('Region wise TotalRevenue Summary')

# Plot the data as a pie chart
df2.TotalRevenue.plot(kind='pie', autopct='%1.2f%%', wedgeprops={'linewidth': 3, 'edgecolor': 'white'})

# Add a legend
plt.legend(title="Regions", loc="center left", bbox_to_anchor=(1, 0.5))

# Save the figure as a PNG file with the specified DPI
fig.savefig('total_revenue_summary.png', dpi=100)

# Display the plot
plt.show()

# %%
ax = df2[['TotalRevenue', 'TotalCost', 'TotalProfit']].plot(stacked=True, kind='bar', legend = True, figsize = (10,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
plt.xticks(rotation=30, ha='center')
for p in ax.patches:
 ax.annotate("{:,.1f}".format(p.get_height()),
 (p.get_x() + p.get_width() / 2., p.get_y()),
 ha='center', va='bottom',
 xytext=(0, 5),
 textcoords='offset points')


# Save the figure as a PNG file with the specified DPI
plt.savefig('Region wise Summary', dpi=100)
