# %% [markdown]
# # Matplot For Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Datasets/Salesrec.csv')

# %%
# df.to_csv('updated-emp.csv', index=False)

# %%
cbr = df.Region.value_counts()
cbr  #cbr is count by region
x = cbr.index
y = cbr.values

# %%
sbr = df.groupby('Region')['Total Revenue'].sum() # sales by region

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
ax =cbr.plot(x=x, y=y, kind='line', legend=False, style='r--')

plt.xticks(rotation=5, ha='center')
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.]),
#  [Text(-1.0, 0, 'North America'),
#   Text(0.0, 0, 'Sub-Saharan Africa'),
#   Text(1.0, 0, 'Europe'),
#   Text(2.0, 0, 'Australia and Oceania'),
#   Text(3.0, 0, 'Asia'),
#   Text(4.0, 0, 'Middle East and North Africa'),
#   Text(5.0, 0, 'Central America and the Caribbean'),
#   Text(6.0, 0, 'North America'),
#   Text(7.0, 0, '')])

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summary')
plt.xlabel('Region')
plt.ylabel('Count')
ax =cbr.plot(x=x, y=y, kind='line', legend=False, style='r--')

plt.xticks(rotation=5, ha='center') 

# add data labels

for i,j in enumerate(y):
    ax.text( i , j , j , ha='left' , va='bottom')

plt.plot(x , y , marker = 'o' , c = 'blue')

# %%
plt.figure(figsize = (15,5)) 
plt.title("Region wise Summery") 
plt.xlabel("Region") 
plt.ylabel("Total Revenue")
           
ax = sbr.plot(x=sbr.index, y=sbr.values, kind="bar", legend=False)
plt.xticks(rotation=5, ha='center');
# Add data labels using text() 
for i, j in enumerate(sbr.values): 
    plt.text(i, j, format(j, ',.1f'), color='black', fontweight='bold', ha='center', va='bottom')

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summery')
plt.xlabel('Region')
plt.ylabel('Count')
ax = cbr.plot(x='Region', y='Count', kind="line", legend=False, style='r--')

plt.xticks(rotation=5, ha='center')

# Adding data labels
for i, j in enumerate(y):
    ax.text(i, j, j, ha='left', va='bottom')

plt.plot(x, y, marker='D', c='blue')
plt.show()

# %%
plt.figure(figsize = (15,5))
plt.title('Region wise Summery')
plt.xlabel('Region')
plt.ylabel('Count')
ax = cbr.plot(x='Region', y='Count', kind="barh", legend=False, style='r--')

plt.xticks(rotation=5, ha='center')


# Adding data labels
for i, j in enumerate(sbr):
    ax.annotate(format(j, ',.1f'),
                (j, i),
                ha='left', va='center',
                xytext= (5,0),
                textcoords='offset points')
plt.show()
