# %%
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv('./Datasets/propData_c.csv')

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0   104.0      PUTNAM            Y           3.0       1.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0       1.5
# 2  100003000.0     NaN   LEXINGTON            N           NaN       1.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0       NaN
# 4          NaN   203.0    BERKELEY            Y           3.0       2.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN       1.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0       NaN
# 7  100008000.0   213.0     TREMONT            Y           1.0       1.0
# 8  100009000.0   215.0     TREMONT            Y           NaN       2.0
#
#     SQ_FT
# 0  1000.0
# 1     NaN
# 2   850.0
# 3   700.0
# 4  1600.0
# 5   800.0
# 6   950.0
# 7     NaN
# 8  1800.0

# %%
df.dtypes
# Out:
# PID             float64
# ST_NUM          float64
# ST_NAME          object
# OWN_OCCUPIED     object
# NUM_BEDROOMS    float64
# NUM_BATH        float64
# SQ_FT           float64
# dtype: object

# %%
df2 = df.dropna(axis=0)
df2 # deleting row with missing data
# Out:
#            PID  ST_NUM ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH   SQ_FT
# 0  100001000.0   104.0  PUTNAM            Y           3.0       1.0  1000.0

# %%
df2 = df.dropna(axis=1, how='any')
df2
# Out:
#       ST_NAME
# 0      PUTNAM
# 1   LEXINGTON
# 2   LEXINGTON
# 3    BERKELEY
# 4    BERKELEY
# 5    BERKELEY
# 6  WASHINGTON
# 7     TREMONT
# 8     TREMONT

# %%
df2 = df.dropna(axis=0, thresh=6) # thresh is min not null val to retain
df2
# Out:
#            PID  ST_NUM    ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH   SQ_FT
# 0  100001000.0   104.0     PUTNAM            Y           3.0       1.0  1000.0
# 1  100002000.0   197.0  LEXINGTON            N           3.0       1.5     NaN
# 4          NaN   203.0   BERKELEY            Y           3.0       2.0  1600.0
# 5  100006000.0   207.0   BERKELEY            Y           NaN       1.0   800.0
# 7  100008000.0   213.0    TREMONT            Y           1.0       1.0     NaN
# 8  100009000.0   215.0    TREMONT            Y           NaN       2.0  1800.0

# %%
avg = df['NUM_BEDROOMS'].mean()
avg
# Out:
# np.float64(2.1666666666666665)

# %%
md = df['NUM_BEDROOMS'].mode()[0]
md
# Out:
# np.float64(3.0)

# %%
mdn = df['NUM_BEDROOMS'].median()
mdn
# Out:
# np.float64(2.5)

# %%
df2 = df.copy()

# %%
df2['NUM_BEDROOMS'] = df2['NUM_BEDROOMS'].fillna(md)
df2
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0   104.0      PUTNAM            Y           3.0       1.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0       1.5
# 2  100003000.0     NaN   LEXINGTON            N           3.0       1.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0       NaN
# 4          NaN   203.0    BERKELEY            Y           3.0       2.0
# 5  100006000.0   207.0    BERKELEY            Y           3.0       1.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0       NaN
# 7  100008000.0   213.0     TREMONT            Y           1.0       1.0
# 8  100009000.0   215.0     TREMONT            Y           3.0       2.0
#
#     SQ_FT
# 0  1000.0
# 1     NaN
# 2   850.0
# 3   700.0
# 4  1600.0
# 5   800.0
# 6   950.0
# 7     NaN
# 8  1800.0

# %%
df2['PID'].fillna(method='bfill', inplace=True)
df2
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12328\1052897978.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['PID'].fillna(method='bfill', inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12328\1052897978.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2['PID'].fillna(method='bfill', inplace=True)
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# ...

# %%
df3 = df2.copy()

# %%
df3['PID'].fillna(method='ffill', inplace=True)
df3
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12328\2861915076.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['PID'].fillna(method='ffill', inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12328\2861915076.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3['PID'].fillna(method='ffill', inplace=True)
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# ...

# %%
df2['SQ_FT'].interpolate(method='linear', limit_direction='forward',inplace=True)
df2
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12328\2831850697.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['SQ_FT'].interpolate(method='linear', limit_direction='forward',inplace=True)
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0   104.0      PUTNAM            Y           3.0       1.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0       1.5
# 2  100003000.0     NaN   LEXINGTON            N           3.0       1.0
# ...
