# %% [markdown]
# # Pandas For Data Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv('F:\Datasets\Salesrec.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Amaan Ul Haq\AppData\Local\Temp\ipykernel_7300\3201417346.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('F:\Datasets\Salesrec.csv')

# %%
# df.to_csv('updated-emp.csv', index=False)

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
print(df.columns)
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
cbr = df.Region.value_counts()
cbr  #cbr is count by region
# Out:
# Region
# Sub-Saharan Africa                   36
# Europe                               22
# Australia and Oceania                11
# Asia                                 11
# Middle East and North Africa         10
# Central America and the Caribbean     7
# North America                         3
# Name: count, dtype: int64

# %%
x = cbr.index
y = cbr.values

# %%
cbr.plot.line(x=x, y=y)
# Out:
# <Axes: xlabel='Region'>

# %%
cbr.plot(x=x, y=y, kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
cbr.plot(x=x, y=y, kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
cbr.plot( x=x , y=y , kind='bar' , figsize=(12,6) , title ='Sales by Region' , 
         xlabel='Region' , ylabel='Sales' , grid=True , rot=70 , fontsize=12 , color='orange')
# Out:
# <Axes: title={'center': 'Sales by Region'}, xlabel='Region', ylabel='Sales'>
