# %% [markdown]
# ## Amaan Ul Haq Siddiqui BDA-06

# %% [markdown]
# ### TASK B

# %% [raw]
# Task B: (45 Marks)
# Given: Dataset: DataSet2.csv
# Required:
# 1. Apply Decision Tree Algorithm,
# 2. Vislaize the Tree
# 3. Show and interpret the confusion Matrix

# %%
import pandas as pdas
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as pt

# %%
df = pdas.read_csv('./ds/DataSet02.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.dropna(inplace=True)

# %%
X = df.drop(columns=['Species'])  
y = df['Species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
pt.figure(figsize=(20, 10))
plot_tree(clf, filled=True, feature_names=X.columns, class_names=clf.classes_, rounded=True, fontsize=10)
pt.title('Decision Tree Visualization', fontsize=16)
pt.show()

# %%
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)

# %%
disp.plot(cmap=pt.cm.Greens)
pt.title('Confusion Matrix', fontsize=14)
pt.show()

# %%
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
